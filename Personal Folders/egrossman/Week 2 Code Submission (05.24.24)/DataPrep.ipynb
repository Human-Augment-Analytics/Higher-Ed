# %% [markdown]
# ## Data Prep
#
# This notebook is for parsing the data and downloading any files. This is to prep for training a multi-modal embedding model

# %%
import pandas as pd
import requests
import json
import uuid

# %% [markdown]
# First we will load the json

# %%
with open("data/sample_occurences.json", "rb") as f:
    jdata = f.read()
occurences = json.loads(jdata)
occurences
# Out:
# [{'offset': 0,
#   'limit': 10,
#   'endOfRecords': False,
#   'count': 23277,
#   'results': [{'key': 4510345615,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:17:07.278+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344229310',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229310/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344229310',
#        'http://purl.org/dc/terms/created': '2024-01-02T13:47:38-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344229315',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229315/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344229315',
#        'http://purl.org/dc/terms/created': '2024-01-02T13:47:30-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344229334',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229334/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344229334',
#        'http://purl.org/dc/terms/created': '2024-01-02T13:47:11-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344229333',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229333/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344229333',
#        'http://purl.org/dc/terms/created': '2024-01-02T13:49:57-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-03T05:32:32',
#     'decimalLatitude': 41.631789,
#     'decimalLongitude': -103.773128,
#     'coordinateUncertaintyInMeters': 27754.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Nebraska',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.28_1', 'name': 'Nebraska'},
#      'level2': {'gid': 'USA.28.4_1', 'name': 'Banner'}},
#     'year': 2024,
#     'month': 1,
#     'day': 2,
#     'eventDate': '2024-01-02T13:47',
#     'startDayOfYear': 2,
#     'endDayOfYear': 2,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-04T05:18:57.000+00:00',
#     'lastInterpreted': '2024-05-20T17:17:07.278+00:00',
#     'references': 'https://www.inaturalist.org/observations/195637303',
#     'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '195637303'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344229334',
#       'created': '2024-01-02T21:47:11.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229334/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344229310',
#       'created': '2024-01-02T21:47:38.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229310/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344229315',
#       'created': '2024-01-02T21:47:30.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229315/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344229333',
#       'created': '2024-01-02T21:49:57.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344229333/original.jpeg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'Colin Croft',
#     'identifiedBy': 'Colin Croft',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'Colin Croft',
#     'identifier': '195637303',
#     'http://unknown.org/nick': 'colincroft',
#     'informationWithheld': 'Coordinate uncertainty increased to 27754m at the request of the observer',
#     'verbatimEventDate': '2024/01/02 1:47 PM',
#     'collectionCode': 'Observations',
#     'gbifID': '4510345615',
#     'verbatimLocality': 'Nebraska, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/195637303',
#     'taxonID': '42007',
#     'catalogNumber': '195637303',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '13:47:00-07:00',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '440102394'},
#    {'key': 4510372143,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:14:53.810+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344540127',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Doug Andrews',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540127/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344540127',
#        'http://purl.org/dc/terms/created': '2024-01-01T18:25:53-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Doug Andrews'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344540130',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Doug Andrews',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540130/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344540130',
#        'http://purl.org/dc/terms/created': '2024-01-01T18:25:55-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Doug Andrews'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344540140',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Doug Andrews',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540140/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344540140',
#        'http://purl.org/dc/terms/created': '2024-01-01T18:25:58-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Doug Andrews'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-04T23:52:09',
#     'decimalLatitude': 33.112376,
#     'decimalLongitude': -116.735213,
#     'coordinateUncertaintyInMeters': 29012.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'California',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.5_1', 'name': 'California'},
#      'level2': {'gid': 'USA.5.37_1', 'name': 'San Diego'}},
#     'year': 2024,
#     'month': 1,
#     'day': 1,
#     'eventDate': '2024-01-01T18:25',
#     'startDayOfYear': 1,
#     'endDayOfYear': 1,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-02-01T03:13:00.000+00:00',
#     'lastInterpreted': '2024-05-20T17:14:53.810+00:00',
#     'references': 'https://www.inaturalist.org/observations/195792898',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '195792898'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344540127',
#       'created': '2024-01-02T02:25:53.000+00:00',
#       'creator': 'Doug Andrews',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Doug Andrews',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540127/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344540140',
#       'created': '2024-01-02T02:25:58.000+00:00',
#       'creator': 'Doug Andrews',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Doug Andrews',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540140/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344540130',
#       'created': '2024-01-02T02:25:55.000+00:00',
#       'creator': 'Doug Andrews',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Doug Andrews',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344540130/original.jpeg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'Doug Andrews',
#     'identifiedBy': 'Doug Andrews',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'Doug Andrews',
#     'identifier': '195792898',
#     'http://unknown.org/nick': 'oldranger',
#     'informationWithheld': 'Coordinate uncertainty increased to 29012m at the request of the observer',
#     'verbatimEventDate': '2024/01/01 6:25 PM',
#     'collectionCode': 'Observations',
#     'gbifID': '4510372143',
#     'verbatimLocality': 'San Diego County, US-CA, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/195792898',
#     'taxonID': '42007',
#     'catalogNumber': '195792898',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '18:25:00-08:00',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '440584493'},
#    {'key': 4510335239,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:50:30.220+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344567383',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'omaha_jack206',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344567383/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344567383',
#        'http://purl.org/dc/terms/created': '2024-01-04T01:33:00Z',
#        'http://purl.org/dc/terms/rightsHolder': 'omaha_jack206'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '344567386',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'omaha_jack206',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344567386/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/344567386',
#        'http://purl.org/dc/terms/created': '2024-01-04T01:33:00Z',
#        'http://purl.org/dc/terms/rightsHolder': 'omaha_jack206'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-05T03:05:24',
#     'decimalLatitude': 33.283069,
#     'decimalLongitude': -116.633894,
#     'coordinateUncertaintyInMeters': 608.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'California',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.5_1', 'name': 'California'},
#      'level2': {'gid': 'USA.5.37_1', 'name': 'San Diego'}},
#     'year': 2024,
#     'month': 1,
#     'day': 3,
#     'eventDate': '2024-01-03T17:33',
#     'startDayOfYear': 3,
#     'endDayOfYear': 3,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-02-01T03:12:58.000+00:00',
#     'lastInterpreted': '2024-05-20T17:50:30.220+00:00',
#     'references': 'https://www.inaturalist.org/observations/195804747',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '195804747'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344567383',
#       'created': '2024-01-04T01:33:00.000+00:00',
#       'creator': 'omaha_jack206',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'omaha_jack206',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344567383/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/344567386',
#       'created': '2024-01-04T01:33:00.000+00:00',
#       'creator': 'omaha_jack206',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'omaha_jack206',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/344567386/original.jpg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'omaha_jack206',
#     'identifiedBy': 'omaha_jack206',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'omaha_jack206',
#     'identifier': '195804747',
#     'http://unknown.org/nick': 'omaha_jack206',
#     'verbatimEventDate': '2024-01-03 17:33:00-08:00',
#     'collectionCode': 'Observations',
#     'gbifID': '4510335239',
#     'verbatimLocality': 'CA-79, Warner Springs, CA, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/195804747',
#     'taxonID': '42007',
#     'catalogNumber': '195804747',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '17:33:00-08:00',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '440618271'},
#    {'key': 4510165116,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:15:07.835+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345079192',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Tom Rickman',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079192/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345079192',
#        'http://purl.org/dc/terms/created': '2024-01-07T10:39:06-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Tom Rickman'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345079202',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Tom Rickman',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079202/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345079202',
#        'http://purl.org/dc/terms/created': '2024-01-07T10:39:16-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Tom Rickman'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345079200',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Tom Rickman',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079200/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345079200',
#        'http://purl.org/dc/terms/created': '2024-01-07T10:39:32-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Tom Rickman'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-07T21:14:28',
#     'decimalLatitude': 40.366586,
#     'decimalLongitude': -120.618539,
#     'coordinateUncertaintyInMeters': 162.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'California',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.5_1', 'name': 'California'},
#      'level2': {'gid': 'USA.5.18_1', 'name': 'Lassen'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T10:39',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-09T03:26:59.000+00:00',
#     'lastInterpreted': '2024-05-20T17:15:07.835+00:00',
#     'references': 'https://www.inaturalist.org/observations/196060253',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196060253'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345079192',
#       'created': '2024-01-07T18:39:06.000+00:00',
#       'creator': 'Tom Rickman',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Tom Rickman',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079192/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345079202',
#       'created': '2024-01-07T18:39:16.000+00:00',
#       'creator': 'Tom Rickman',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Tom Rickman',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079202/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345079200',
#       'created': '2024-01-07T18:39:32.000+00:00',
#       'creator': 'Tom Rickman',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'Tom Rickman',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345079200/original.jpeg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'Tom Rickman',
#     'identifiedBy': 'Tom Rickman',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'Tom Rickman',
#     'identifier': '196060253',
#     'http://unknown.org/nick': 'trickman',
#     'verbatimEventDate': '2024/01/07 10:39 AM',
#     'collectionCode': 'Observations',
#     'gbifID': '4510165116',
#     'verbatimLocality': 'Lassen County, CA, USA',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196060253',
#     'taxonID': '42007',
#     'catalogNumber': '196060253',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '10:39:00-08:00',
#     'occurrenceRemarks': 'Odd drag marks.',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441358517'},
#    {'key': 4510152112,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:11:38.412+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119520',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119520/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119520',
#        'http://purl.org/dc/terms/created': '2024-01-07T20:25:44Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119544',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119544/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119544',
#        'http://purl.org/dc/terms/created': '2024-01-07T20:25:44Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-08T01:10:18',
#     'decimalLatitude': 47.376227,
#     'decimalLongitude': -113.67616,
#     'coordinateUncertaintyInMeters': 2.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Montana',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.27_1', 'name': 'Montana'},
#      'level2': {'gid': 'USA.27.32_1', 'name': 'Missoula'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T13:25:44',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-08T14:47:21.000+00:00',
#     'lastInterpreted': '2024-05-20T17:11:38.412+00:00',
#     'references': 'https://www.inaturalist.org/observations/196080179',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196080179'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345119544',
#       'created': '2024-01-07T20:25:44.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119544/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345119520',
#       'created': '2024-01-07T20:25:44.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119520/original.jpg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'W. Terry Hunefeld',
#     'identifiedBy': 'W. Terry Hunefeld',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'W. Terry Hunefeld',
#     'identifier': '196080179',
#     'http://unknown.org/nick': 'thunefeld',
#     'verbatimEventDate': '2024-01-07 13:25:44-07:00',
#     'collectionCode': 'Observations',
#     'gbifID': '4510152112',
#     'verbatimLocality': 'Missoula County, US-MT, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196080179',
#     'taxonID': '42007',
#     'catalogNumber': '196080179',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '13:25:44-07:00',
#     'occurrenceRemarks': 'Tracks',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441412374'},
#    {'key': 4510183154,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:11:54.283+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119590',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119590/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119590',
#        'http://purl.org/dc/terms/created': '2024-01-07T20:54:48Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119627',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119627/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119627',
#        'http://purl.org/dc/terms/created': '2024-01-07T20:54:48Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119687',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119687/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119687',
#        'http://purl.org/dc/terms/created': '2024-01-07T20:54:48Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-08T01:10:55',
#     'decimalLatitude': 47.375395,
#     'decimalLongitude': -113.676058,
#     'coordinateUncertaintyInMeters': 24.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Montana',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.27_1', 'name': 'Montana'},
#      'level2': {'gid': 'USA.27.32_1', 'name': 'Missoula'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T13:54:48',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-02-01T03:14:03.000+00:00',
#     'lastInterpreted': '2024-05-20T17:11:54.283+00:00',
#     'references': 'https://www.inaturalist.org/observations/196080216',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196080216'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345119627',
#       'created': '2024-01-07T20:54:48.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119627/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345119687',
#       'created': '2024-01-07T20:54:48.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119687/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345119590',
#       'created': '2024-01-07T20:54:48.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119590/original.jpg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'W. Terry Hunefeld',
#     'identifiedBy': 'W. Terry Hunefeld',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'W. Terry Hunefeld',
#     'identifier': '196080216',
#     'http://unknown.org/nick': 'thunefeld',
#     'verbatimEventDate': '2024-01-07 13:54:48-07:00',
#     'collectionCode': 'Observations',
#     'gbifID': '4510183154',
#     'verbatimLocality': 'Missoula County, US-MT, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196080216',
#     'taxonID': '42007',
#     'catalogNumber': '196080216',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '13:54:48-07:00',
#     'occurrenceRemarks': 'Tracks',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441412470'},
#    {'key': 4510149082,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:50:16.411+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345119910',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345119910/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345119910',
#        'http://purl.org/dc/terms/created': '2024-01-07T21:15:08Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345120095',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120095/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345120095',
#        'http://purl.org/dc/terms/created': '2024-01-07T21:15:08Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345120366',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120366/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345120366',
#        'http://purl.org/dc/terms/created': '2024-01-07T21:15:08Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345120710',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120710/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345120710',
#        'http://purl.org/dc/terms/created': '2024-01-07T21:15:08Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345120891',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'W. Terry Hunefeld',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120891/original.jpg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345120891',
#        'http://purl.org/dc/terms/created': '2024-01-07T21:15:08Z',
#        'http://purl.org/dc/terms/rightsHolder': 'W. Terry Hunefeld'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-08T01:11:59',
#     'decimalLatitude': 47.374962,
#     'decimalLongitude': -113.675833,
#     'coordinateUncertaintyInMeters': 5.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Montana',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.27_1', 'name': 'Montana'},
#      'level2': {'gid': 'USA.27.32_1', 'name': 'Missoula'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T14:15:08',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-08T14:47:59.000+00:00',
#     'lastInterpreted': '2024-05-20T17:50:16.411+00:00',
#     'references': 'https://www.inaturalist.org/observations/196080288',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196080288'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345120891',
#       'created': '2024-01-07T21:15:08.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120891/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345120366',
#       'created': '2024-01-07T21:15:08.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120366/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345120095',
#       'created': '2024-01-07T21:15:08.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'W. Terry Hunefeld',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345120095/original.jpg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345120710',
#       'created': '2024-01-07T21:15:08.000+00:00',
#       'creator': 'W. Terry Hunefeld',
#       'publisher': 'iNaturalist',
# ...
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T19:17:13',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-02-26T05:10:28.000+00:00',
#     'lastInterpreted': '2024-05-20T17:12:19.886+00:00',
#     'references': 'https://www.inaturalist.org/observations/196090386',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196090386'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345140108',
#       'created': '2024-01-08T03:17:13.000+00:00',
#       'creator': 'deadbitxch',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'rightsHolder': 'deadbitxch',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345140108/original.jpg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'deadbitxch',
#     'identifiedBy': 'deadbitxch',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'deadbitxch',
#     'identifier': '196090386',
#     'http://unknown.org/nick': 'deadbitxch',
#     'verbatimEventDate': '2024-01-07 19:17:13-08:00',
#     'collectionCode': 'Observations',
#     'gbifID': '4510163092',
#     'verbatimLocality': 'Mt. Woodson, Poway, CA, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196090386',
#     'taxonID': '143589',
#     'catalogNumber': '196090386',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '19:17:13-08:00',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441438691'},
#    {'key': 4510180091,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:11:39.331+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345143329',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143329/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345143329',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:08:51-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345143306',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143306/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345143306',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:09:25-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345143444',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143444/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345143444',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:09:18-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-08T03:45:50',
#     'decimalLatitude': 41.776904,
#     'decimalLongitude': -103.752034,
#     'coordinateUncertaintyInMeters': 27754.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Nebraska',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.28_1', 'name': 'Nebraska'},
#      'level2': {'gid': 'USA.28.79_1', 'name': 'Scotts Bluff'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T14:08',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-08T14:49:26.000+00:00',
#     'lastInterpreted': '2024-05-20T17:11:39.331+00:00',
#     'references': 'https://www.inaturalist.org/observations/196091915',
#     'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196091915'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345143306',
#       'created': '2024-01-07T22:09:25.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143306/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345143444',
#       'created': '2024-01-07T22:09:18.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143444/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345143329',
#       'created': '2024-01-07T22:08:51.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345143329/original.jpeg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'Colin Croft',
#     'identifiedBy': 'Colin Croft',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'Colin Croft',
#     'identifier': '196091915',
#     'http://unknown.org/nick': 'colincroft',
#     'informationWithheld': 'Coordinate uncertainty increased to 27754m at the request of the observer',
#     'verbatimEventDate': '2024/01/07 2:08 PM',
#     'collectionCode': 'Observations',
#     'gbifID': '4510180091',
#     'verbatimLocality': 'Nebraska, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196091915',
#     'taxonID': '42007',
#     'catalogNumber': '196091915',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '14:08:00-07:00',
#     'occurrenceRemarks': 'scrape',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441443444'},
#    {'key': 4510174211,
#     'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#     'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#     'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#     'publishingCountry': 'US',
#     'protocol': 'DWC_ARCHIVE',
#     'lastCrawled': '2024-05-20T03:40:30.646+00:00',
#     'lastParsed': '2024-05-20T17:50:36.074+00:00',
#     'crawlId': 459,
#     'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345144001',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144001/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345144001',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:12:14-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345144042',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144042/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345144042',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:12:30-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'},
#       {'http://purl.org/dc/terms/format': 'image/jpeg',
#        'http://rs.tdwg.org/dwc/terms/catalogNumber': '345144028',
#        'http://purl.org/dc/terms/type': 'StillImage',
#        'http://purl.org/dc/terms/publisher': 'iNaturalist',
#        'http://purl.org/dc/terms/creator': 'Colin Croft',
#        'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#        'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144028/original.jpeg',
#        'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/345144028',
#        'http://purl.org/dc/terms/created': '2024-01-07T14:12:40-08:00',
#        'http://purl.org/dc/terms/rightsHolder': 'Colin Croft'}]},
#     'basisOfRecord': 'HUMAN_OBSERVATION',
#     'occurrenceStatus': 'PRESENT',
#     'taxonKey': 2435099,
#     'kingdomKey': 1,
#     'phylumKey': 44,
#     'classKey': 359,
#     'orderKey': 732,
#     'familyKey': 9703,
#     'genusKey': 2435098,
#     'speciesKey': 2435099,
#     'acceptedTaxonKey': 2435099,
#     'scientificName': 'Puma concolor (Linnaeus, 1771)',
#     'acceptedScientificName': 'Puma concolor (Linnaeus, 1771)',
#     'kingdom': 'Animalia',
#     'phylum': 'Chordata',
#     'order': 'Carnivora',
#     'family': 'Felidae',
#     'genus': 'Puma',
#     'species': 'Puma concolor',
#     'genericName': 'Puma',
#     'specificEpithet': 'concolor',
#     'taxonRank': 'SPECIES',
#     'taxonomicStatus': 'ACCEPTED',
#     'iucnRedListCategory': 'LC',
#     'dateIdentified': '2024-01-08T03:52:50',
#     'decimalLatitude': 41.78966,
#     'decimalLongitude': -103.7595,
#     'coordinateUncertaintyInMeters': 27754.0,
#     'continent': 'NORTH_AMERICA',
#     'stateProvince': 'Nebraska',
#     'gadm': {'level0': {'gid': 'USA', 'name': 'United States'},
#      'level1': {'gid': 'USA.28_1', 'name': 'Nebraska'},
#      'level2': {'gid': 'USA.28.79_1', 'name': 'Scotts Bluff'}},
#     'year': 2024,
#     'month': 1,
#     'day': 7,
#     'eventDate': '2024-01-07T14:12',
#     'startDayOfYear': 7,
#     'endDayOfYear': 7,
#     'issues': ['COORDINATE_ROUNDED',
#      'CONTINENT_DERIVED_FROM_COORDINATES',
#      'TAXON_MATCH_TAXON_ID_IGNORED'],
#     'modified': '2024-01-08T14:49:41.000+00:00',
#     'lastInterpreted': '2024-05-20T17:50:36.074+00:00',
#     'references': 'https://www.inaturalist.org/observations/196092487',
#     'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#     'isSequenced': False,
#     'identifiers': [{'identifier': '196092487'}],
#     'media': [{'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345144042',
#       'created': '2024-01-07T22:12:30.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144042/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345144028',
#       'created': '2024-01-07T22:12:40.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144028/original.jpeg'},
#      {'type': 'StillImage',
#       'format': 'image/jpeg',
#       'references': 'https://www.inaturalist.org/photos/345144001',
#       'created': '2024-01-07T22:12:14.000+00:00',
#       'creator': 'Colin Croft',
#       'publisher': 'iNaturalist',
#       'license': 'http://creativecommons.org/licenses/by/4.0/',
#       'rightsHolder': 'Colin Croft',
#       'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/345144001/original.jpeg'}],
#     'facts': [],
#     'relations': [],
#     'isInCluster': False,
#     'datasetName': 'iNaturalist research-grade observations',
#     'recordedBy': 'Colin Croft',
#     'identifiedBy': 'Colin Croft',
#     'geodeticDatum': 'WGS84',
#     'class': 'Mammalia',
#     'countryCode': 'US',
#     'recordedByIDs': [],
#     'identifiedByIDs': [],
#     'gbifRegion': 'NORTH_AMERICA',
#     'country': 'United States of America',
#     'publishedByGbifRegion': 'NORTH_AMERICA',
#     'rightsHolder': 'Colin Croft',
#     'identifier': '196092487',
#     'http://unknown.org/nick': 'colincroft',
#     'informationWithheld': 'Coordinate uncertainty increased to 27754m at the request of the observer',
#     'verbatimEventDate': '2024/01/07 2:12 PM',
#     'collectionCode': 'Observations',
#     'gbifID': '4510174211',
#     'verbatimLocality': 'Nebraska, US',
#     'occurrenceID': 'https://www.inaturalist.org/observations/196092487',
#     'taxonID': '42007',
#     'catalogNumber': '196092487',
#     'institutionCode': 'iNaturalist',
#     'eventTime': '14:12:00-07:00',
#     'occurrenceRemarks': 'scrape',
#     'http://unknown.org/captive': 'wild',
#     'identificationID': '441444888'}],
#   'facets': []}]

# %%
print("First level of keys:")
print(occurences[0].keys())
print("\n")


occ= occurences[0]
print("Length of Results:")
print(len(occ["results"]))

res = occ["results"][0]
print("Result Keys:")
print(res.keys())

print("\n")
print("Species Id, Name, Generic Name")
print(res["speciesKey"], res["acceptedScientificName"], res["genericName"])
print("\n")

print("Media Length")
print(len(res["media"]))
med = res["media"][0]
# Out:
# First level of keys:
# dict_keys(['offset', 'limit', 'endOfRecords', 'count', 'results', 'facets'])
#
#
# Length of Results:
# 10
# Result Keys:
# dict_keys(['key', 'datasetKey', 'publishingOrgKey', 'installationKey', 'hostingOrganizationKey', 'publishingCountry', 'protocol', 'lastCrawled', 'lastParsed', 'crawlId', 'extensions', 'basisOfRecord', 'occurrenceStatus', 'taxonKey', 'kingdomKey', 'phylumKey', 'classKey', 'orderKey', 'familyKey', 'genusKey', 'speciesKey', 'acceptedTaxonKey', 'scientificName', 'acceptedScientificName', 'kingdom', 'phylum', 'order', 'family', 'genus', 'species', 'genericName', 'specificEpithet', 'taxonRank', 'taxonomicStatus', 'iucnRedListCategory', 'dateIdentified', 'decimalLatitude', 'decimalLongitude', 'coordinateUncertaintyInMeters', 'continent', 'stateProvince', 'gadm', 'year', 'month', 'day', 'eventDate', 'startDayOfYear', 'endDayOfYear', 'issues', 'modified', 'lastInterpreted', 'references', 'license', 'isSequenced', 'identifiers', 'media', 'facts', 'relations', 'isInCluster', 'datasetName', 'recordedBy', 'identifiedBy', 'geodeticDatum', 'class', 'countryCode', 'recordedByIDs', 'identifiedByIDs', 'gbifRegion', 'country', 'publishedByGbifRegion', 'rightsHolder', 'identifier', 'http://unknown.org/nick', 'informationWithheld', 'verbatimEventDate', 'collectionCode', 'gbifID', 'verbatimLocality', 'occurrenceID', 'taxonID', 'catalogNumber', 'institutionCode', 'eventTime', 'http://unknown.org/captive', 'identificationID'])
#
#
# Species Id, Name, Generic Name
# 2435099 Puma concolor (Linnaeus, 1771) Puma
#
#
# Media Length
# 4

# %% [markdown]
# ## Scripting data
#
# For each record, we are going to pull the taxonomy Id, generic name, and pictures
#
# first, let's define a method that reads in a media dict and downloads the file and returns the file location

# %%
def download_media(media_dict):
    """Downloads the picture in the media link (png, jpeg, etc) to the data folder and returns the image
    
    Ketword Arguments:
    media_dict -- a single media object with multiple links from the GBIF dataset
    """
    file_name = media_dict["identifier"]
    extension = file_name.split(".")[-1]

    identifier = str(uuid.uuid4())

    new_file_name = identifier + "." + extension

    file_path = "data/images/" + new_file_name
    
    image_data = requests.get(file_name).content
    
    with open(file_path, "wb") as f:
        f.write(image_data)
    return new_file_name

# %% [markdown]
# Now we can parse all the records and save them as a csv along with picture locations as an array

# %%
def parse_records(occurences):
    """Parses the IDIGBIO json to extract species, description, and media locations
    Keyword Arguments: occurences: list of occurances
    """

    for occurence in occurences:

        database = []

        for record in occurence["results"]:

            record_dict = {}

            record_dict["id"] = record["key"]
            record_dict["speciesKey"] = record["speciesKey"]
            record_dict["scienceName"] = record["acceptedScientificName"]
            record_dict["simpleName"] = record["genericName"]
            record_dict["dataset"] = record["datasetName"]


            media_files = []

            for media in record["media"]:

                file_name = download_media(media)
                media_files.append(file_name)

            record_dict["media"] = media_files

    df = pd.DataFrame(record_dict)
    df.to_csv("data/input.csv")

    return df

# %%
parse_records(occurences)
# Out:
#            id  speciesKey                     scienceName simpleName  \
# 0  4510174211     2435099  Puma concolor (Linnaeus, 1771)       Puma
# 1  4510174211     2435099  Puma concolor (Linnaeus, 1771)       Puma
# 2  4510174211     2435099  Puma concolor (Linnaeus, 1771)       Puma
#
#                                    dataset  \
# 0  iNaturalist research-grade observations
# 1  iNaturalist research-grade observations
# 2  iNaturalist research-grade observations
#
#                                        media
# 0  9ba6376e-97c8-4f9c-b991-dbaa4b19c0f7.jpeg
# 1  a36874aa-4370-4154-be00-5eb92d7989de.jpeg
# 2  9a32b0c5-8fc5-4311-a6f2-8fac40543298.jpeg
