# %%
# Imports
import yaml
import deeplabcut

# Path to Config
config_path = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml"

# Load the Config
with open(config_path, 'r') as file:
    config_data = yaml.safe_load(file)
    
# Pose Config Path
pose_cfg_path = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/dlc-models-pytorch/iteration-0/dlc_modelJul26-trainset95shuffle1/train/pose_cfg.yaml"

# Load the Pose Config Yaml
with open(pose_cfg_path, 'r') as file:
    pose_cfg = yaml.safe_load(file)

# Print Contents of Pose Config
# print(pose_cfg)

# Use Config, Create Test Set
# deeplabcut.create_multianimaltraining_dataset(config_path, trainIndices=None)
# Out:
# Loading DLC 3.0.0rc5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
# Evaluate Network with Plotting to Visualize Performance
deeplabcut.evaluate_network(config_path, plotting=True)
# Out:
# /home/hice1/kcozart6/.conda/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/pose_estimation_pytorch/runners/base.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
video_path = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4"  
video_folder = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos"  
config_path='/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml'

# try
# videofile_path = os.path.join(os.getcwd(),'dlc_model-student-2023-07-26','videos','0001_vid_30secs_converted2.mp4')
# deeplabcut.analyze_videos(path_config_file,[videofile_path], shuffle=shuffle)
    
# Step 4: Create labeled video frames after evaluation
# This will overlay the labels on the video and generate a new labeled video
scorername = deeplabcut.analyze_videos(config_path, ["/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4"], videotype='.mp4')
#deeplabcut.analyze_videos(config_path, video_path)
#deeplabcut.filterpredictions(config_path, video_path, shuffle=1)
deeplabcut.create_video_with_all_detections(config_path, ["/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4"], videotype='.mp4')
#deeplabcut.create_labeled_video(config_path, video_path)

# Optional: If you prefer saving individual labeled frames as images instead of a video, you can enable the save_frames argument.
# deeplabcut.create_labeled_video(config_path, video_path, save_frames=True)

# %% [markdown]
# ### garbage

# %%
# Imports
import torch

# Create Detections
normal_repr = torch.Tensor.__repr__
torch.Tensor.__repr__ = lambda self: f"{self.shape}_{normal_repr(self)}"
config_path = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml"
scorername = deeplabcut.analyze_videos(config_path,['/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs_converted2.mp4'], videotype='mp4')
deeplabcut.create_video_with_all_detections(config_path, ['/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs_converted2.mp4'], videotype='mp4')
# Out:
# Analyzing videos with /storage/ice1/0/3/kcozart6/dlc_model-student-2023-07-26/dlc-models-pytorch/iteration-0/dlc_modelJul26-trainset95shuffle1/train/snapshot-180.pt
# ...

# %%
# Evaluate Network with Plotting to Visualize Performance
deeplabcut.evaluate_network(config_path, plotting=True)
# Out:
# /home/hice1/kcozart6/.conda/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/pose_estimation_pytorch/runners/base.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
video_path = ["/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4"]  
config_path='/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml'
    
# Step 4: Create labeled video frames after evaluation
# This will overlay the labels on the video and generate a new labeled video
deeplabcut.analyze_videos(config_path, ['0001_vid_30secs.mp4'], shuffle=1, save_as_csv=True)
deeplabcut.create_labeled_video(config_path, video_path)

# Optional: If you prefer saving individual labeled frames as images instead of a video, you can enable the save_frames argument.
# deeplabcut.create_labeled_video(config_path, video_path, save_frames=True)
# Out:
# Starting to process video: /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4
# Loading /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/0001_vid_30secs.mp4 and data.
# No unfiltered data file found in /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos for video 0001_vid_30secs and scorer DLC_Resnet50_dlc_modelJul26shuffle1_snapshot_180 and ellipse tracker.
# [False]

# %%
print(config_path)
print(len(['/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4']))
# Out:
# /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml
# 1

# %% [markdown]
# ### Test

# %%
video_path = ["/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4"]  
config_path='/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml'
    
# Step 4: Create labeled video frames after evaluation
# This will overlay the labels on the video and generate a new labeled video
deeplabcut.create_labeled_video(config_path, video_path)

# Optional: If you prefer saving individual labeled frames as images instead of a video, you can enable the save_frames argument.
# deeplabcut.create_labeled_video(config_path, video_path, save_frames=True)
# Out:
# Starting to process video: /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4
# Loading /home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/videos/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4 and data.
# Duration of video [s]: 18.07, recorded with 30.0 fps!
# Overall # of frames: 542 with cropped frame dimensions: 150 150
# Generating frames and creating video.
# /home/hice1/kcozart6/.conda/envs/DEEPLABCUT/lib/python3.10/site-packages/deeplabcut/utils/make_labeled_video.py:140: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# 100%|██████████| 542/542 [00:01<00:00, 519.31it/s]
# [True]

# %%
import deeplabcut
import torch

normal_repr = torch.Tensor.__repr__
torch.Tensor.__repr__ = lambda self: f"{self.shape}_{normal_repr(self)}"

config_path = "/home/hice1/kcozart6/scratch/dlc_model-student-2023-07-26/config.yaml"

scorername = deeplabcut.analyze_videos(config_path,['/home/hice1/kcozart6/scratch/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4'], videotype='.mp4')
deeplabcut.create_video_with_all_detections(config_path, ['/home/hice1/kcozart6/scratch/MC_singlenuc37_2_Tk17_030320__0001_vid__3305.mp4'], videotype='.mp4')
# Out:
# Loading DLC 3.0.0rc5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# Analyzing videos with /storage/ice1/0/3/kcozart6/dlc_model-student-2023-07-26/dlc-models-pytorch/iteration-0/dlc_modelJul26-trainset95shuffle1/train/snapshot-180.pt
# ...
