# %%
import matplotlib.pyplot as plt

# Data for plotting (epoch training losses)
epochs = list(range(1, 50))
train_losses = [
    0.00666, 0.00338, 0.00283, 0.00254, 0.00247, 0.00236, 0.00258, 0.00247, 0.00372, 
    0.00212, 0.00263, 0.00247, 0.00242, 0.00272, 0.00257, 0.00191, 0.00229, 0.00195, 
    0.00354, 0.00293, 0.00213, 0.00201, 0.00228, 0.00212, 0.00202, 0.00247, 0.00335, 
    0.00201, 0.00187, 0.00181, 0.00180, 0.00170, 0.00174, 0.00181, 0.00165, 0.00183, 
    0.00192, 0.00199, 0.00196, 0.00175, 0.00153, 0.00153, 0.00163, 0.00265, 0.00153, 
    0.00169, 0.00163, 0.00366, 0.00339
]

# Plotting the train loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', color='b', label='Training Loss')

# Adding labels and title
plt.title('Training Loss over Epochs - Wall Time 08:43:48 - Out of Mem (BatchSize:1, EvalInterval:10, Overwritten)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import re

# Log data (your input)
log_data = '''
Epoch 1/200 (lr=0.0001), train loss 0.00988
Epoch 2/200 (lr=0.0001), train loss 0.01213
Epoch 3/200 (lr=0.0001), train loss 0.00985
Epoch 4/200 (lr=0.0001), train loss 0.00887
Epoch 5/200 (lr=0.0001), train loss 0.01176
Epoch 6/200 (lr=0.0001), train loss 0.01016
Epoch 7/200 (lr=0.0001), train loss 0.01129
Epoch 8/200 (lr=0.0001), train loss 0.00840
Epoch 9/200 (lr=0.0001), train loss 0.00662
Epoch 10/200 (lr=0.0001), train loss 0.00476
Epoch 11/200 (lr=0.0001), train loss 0.00626
Epoch 12/200 (lr=0.0001), train loss 0.00361
Epoch 13/200 (lr=0.0001), train loss 0.00620
Epoch 14/200 (lr=0.0001), train loss 0.00437
Epoch 15/200 (lr=0.0001), train loss 0.00355
Epoch 16/200 (lr=0.0001), train loss 0.00348
Epoch 17/200 (lr=0.0001), train loss 0.00368
Epoch 18/200 (lr=0.0001), train loss 0.00389
Epoch 19/200 (lr=0.0001), train loss 0.00326
Epoch 20/200 (lr=0.0001), train loss 0.00288
Epoch 21/200 (lr=0.0001), train loss 0.00282
Epoch 22/200 (lr=0.0001), train loss 0.00275
Epoch 23/200 (lr=0.0001), train loss 0.00294
Epoch 24/200 (lr=0.0001), train loss 0.00321
Epoch 25/200 (lr=0.0001), train loss 0.00283
Epoch 26/200 (lr=0.0001), train loss 0.00278
Epoch 27/200 (lr=0.0001), train loss 0.00256
Epoch 28/200 (lr=0.0001), train loss 0.00285
Epoch 29/200 (lr=0.0001), train loss 0.00273
Epoch 30/200 (lr=0.0001), train loss 0.00269
Epoch 31/200 (lr=0.0001), train loss 0.00351
Epoch 32/200 (lr=0.0001), train loss 0.00475
Epoch 33/200 (lr=0.0001), train loss 0.00357
Epoch 34/200 (lr=0.0001), train loss 0.00376
Epoch 35/200 (lr=0.0001), train loss 0.00293
Epoch 36/200 (lr=0.0001), train loss 0.00254
Epoch 37/200 (lr=0.0001), train loss 0.00275
Epoch 38/200 (lr=0.0001), train loss 0.00250
Epoch 39/200 (lr=0.0001), train loss 0.00231
Epoch 40/200 (lr=0.0001), train loss 0.00212
Epoch 41/200 (lr=0.0001), train loss 0.00259
Epoch 42/200 (lr=0.0001), train loss 0.00244
Epoch 43/200 (lr=0.0001), train loss 0.00222
Epoch 44/200 (lr=0.0001), train loss 0.00222
Epoch 45/200 (lr=0.0001), train loss 0.00210
Epoch 46/200 (lr=0.0001), train loss 0.00212
Epoch 47/200 (lr=0.0001), train loss 0.00211
Epoch 48/200 (lr=0.0001), train loss 0.00207
Epoch 49/200 (lr=0.0001), train loss 0.00204
'''

# Use regular expression to find all occurrences of train loss values
train_losses = re.findall(r'train loss ([0-9]*\.[0-9]+)', log_data)

# Convert the extracted strings to float values
train_losses = [float(loss) for loss in train_losses]

# Print the array of train losses
print(train_losses)
# Out:
# [0.00988, 0.01213, 0.00985, 0.00887, 0.01176, 0.01016, 0.01129, 0.0084, 0.00662, 0.00476, 0.00626, 0.00361, 0.0062, 0.00437, 0.00355, 0.00348, 0.00368, 0.00389, 0.00326, 0.00288, 0.00282, 0.00275, 0.00294, 0.00321, 0.00283, 0.00278, 0.00256, 0.00285, 0.00273, 0.00269, 0.00351, 0.00475, 0.00357, 0.00376, 0.00293, 0.00254, 0.00275, 0.0025, 0.00231, 0.00212, 0.00259, 0.00244, 0.00222, 0.00222, 0.0021, 0.00212, 0.00211, 0.00207, 0.00204]

# %%
import matplotlib.pyplot as plt

# Data for plotting (epoch training losses)
epochs = list(range(1, 50))

# Plotting the train loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', color='b', label='Training Loss')

# Adding labels and title
plt.title('Training Loss over Epochs - Wall Time 03:50:38+ - In-Progress (BatchSize:16, EvalInterval:300, Poor Performance Fix Made)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()
